# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### 1 insert

# %%
df1 = pd.DataFrame({'a':[10,20,30],'b':[5,6,7],'c':[3,4,5]})

# %%
df1
# Out:
#     a  b  c
# 0  10  5  3
# 1  20  6  4
# 2  30  7  5

# %%
df1.insert(1,'D','Python') # Column will be added at 1st index
df1
# Out:
#     a       D  b  c
# 0  10  Python  5  3
# 1  20  Python  6  4
# 2  30  Python  7  5

# %%
df1
# Out:
#     a       D  b  c
# 0  10  Python  5  3
# 1  20  Python  6  4
# 2  30  Python  7  5

# %%
df1.insert(1,'F',['Python','a',6])# column will be added at 1st index
df1
# Out:
#     a       F       D  b  c
# 0  10  Python  Python  5  3
# 1  20       a  Python  6  4
# 2  30       6  Python  7  5

# %%
df1.insert(1,'E',['Python','a','A'], allow_duplicates=True) # column will be added at 1st index

# %%
df1
# Out:
#     a       E       F       D  b  c
# 0  10  Python  Python  Python  5  3
# 1  20       a       a  Python  6  4
# 2  30       A       6  Python  7  5

# %% [markdown]
# ## Merge DataFrame
# ### 1.append()

# %%
# df1.append(df_list)
# df1.append([df2,df3,df4])
# df_new =df1.append(df2)

# %%
chr(65)
# Out:
# 'A'

# %%
chr(122)
# Out:
# 'z'

# %%
d = {'ASCII_Value':[i for i in range(65,70)],
     'char' : [chr(i) for i in range(65,70)]}
d
# Out:
# {'ASCII_Value': [65, 66, 67, 68, 69], 'char': ['A', 'B', 'C', 'D', 'E']}

# %%
import pandas as pd

# %%
chr(90)
# Out:
# 'Z'

# %%
df2 = pd.DataFrame({'ASCII_Value':[i for i in range(65,70)],
                    'char': [chr(i) for i in range(65,70)]})
df2
# Out:
#    ASCII_Value char
# 0           65    A
# 1           66    B
# 2           67    C
# 3           68    D
# 4           69    E

# %%
df3 = pd.DataFrame({'ASCII_Value':[i for i in range(70,74)],
                    'char': [chr(i) for i in range(70,74)]})
df3
# Out:
#    ASCII_Value char
# 0           70    F
# 1           71    G
# 2           72    H
# 3           73    I

# %%
df4 = pd.DataFrame({'ASCII_Value':[i for i in range(75,78)],
                    'chr': [chr(i) for i in range(75,78)]})
df4
# Out:
#    ASCII_Value chr
# 0           75   K
# 1           76   L
# 2           77   M

# %%
df_new = pd.concat([df2,df3], ignore_index=True)
df_new
# Out:
#    ASCII_Value char
# 0           70    F
# 1           71    G
# 2           72    H
# 3           73    I
# 4           70    F
# 5           71    G
# 6           72    H
# 7           73    I

# %% [markdown]
# ### 2.concat()

# %%
df_new = pd.concat([df2,df3], ignore_index=True)
df_new
# Out:
#    ASCII_Value char
# 0           70    F
# 1           71    G
# 2           72    H
# 3           73    I
# 4           70    F
# 5           71    G
# 6           72    H
# 7           73    I

# %%
df_new = pd.concat([df2,df3], axis=1, ignore_index=True)
df_new
# Out:
#     0  1   2  3
# 0  70  F  70  F
# 1  71  G  71  G
# 2  72  H  72  H
# 3  73  I  73  I

# %%
df_new = pd.concat([df2,df3], axis=1)
df_new
# Out:
#    ASCII_Value char  ASCII_Value char
# 0           70    F           70    F
# 1           71    G           71    G
# 2           72    H           72    H
# 3           73    I           73    I

# %%
df5 = pd.concat([df2,df4], ignore_index=True)
df5
# Out:
#    ASCII_Value char  chr
# 0           70    F  NaN
# 1           71    G  NaN
# 2           72    H  NaN
# 3           73    I  NaN
# 4           75  NaN    K
# 5           76  NaN    L
# 6           77  NaN    M

# %%
df6 = pd.concat([df2,df4], axis=1)
df6
# Out:
#    ASCII_Value char  ASCII_Value  chr
# 0           70    F         75.0    K
# 1           71    G         76.0    L
# 2           72    H         77.0    M
# 3           73    I          NaN  NaN

# %%
df7 = pd.concat([df4,df3], axis=1)
df7
# Out:
#    ASCII_Value  chr  ASCII_Value char
# 0         75.0    K           70    F
# 1         76.0    L           71    G
# 2         77.0    M           72    H
# 3          NaN  NaN           73    I

# %%
df8 = pd.concat([df2,df4], axis=1, join='inner')
df8
# Out:
#    ASCII_Value char  ASCII_Value chr
# 0           70    F           75   K
# 1           71    G           76   L
# 2           72    H           77   M

# %%
df9 = pd.concat([df2,df4], axis=1, join='outer')
df9
# Out:
#    ASCII_Value char  ASCII_Value  chr
# 0           70    F         75.0    K
# 1           71    G         76.0    L
# 2           72    H         77.0    M
# 3           73    I          NaN  NaN

# %% [markdown]
# ### Apply function()

# %%
# df.apply(fun_name)

# %%
import numpy as np
import pandas as pd

# %%
matrix = np.random.randint(1,20,size=(5,5))
matrix
# Out:
# array([[15, 12, 14,  4,  1],
#        [15, 17, 13,  9, 15],
#        [10, 19,  5, 18, 10],
#        [ 8,  7, 11,  1,  2],
#        [11, 19, 19, 10,  7]])

# %%
df01 = pd.DataFrame(matrix, columns=list('abcde'))
df01
# Out:
#     a   b   c   d   e
# 0  15  12  14   4   1
# 1  15  17  13   9  15
# 2  10  19   5  18  10
# 3   8   7  11   1   2
# 4  11  19  19  10   7

# %%
def square(df):
    return df**2

# %%
df01.apply(square)
# Out:
#      a    b    c    d    e
# 0  225  144  196   16    1
# 1  225  289  169   81  225
# 2  100  361   25  324  100
# 3   64   49  121    1    4
# 4  121  361  361  100   49

# %%
df01.insert(1,'D','Python') # column will be added at 1st index
df01
# Out:
#     a       D   b   c   d   e
# 0  15  Python  12  14   4   1
# 1  15  Python  17  13   9  15
# 2  10  Python  19   5  18  10
# 3   8  Python   7  11   1   2
# 4  11  Python  19  19  10   7

# %%
df01.apply(square)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\ops\array_ops.py:218, in _na_arithmetic_op(left, right, op, is_cmp)
#     217 try:
# --> 218     result = func(left, right)
#     219 except TypeError:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\computation\expressions.py:242, in evaluate(op, a, b, use_numexpr)
#     240     if use_numexpr:
#     241         # error: "None" not callable
# --> 242         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     243 return _evaluate_standard(op, op_str, a, b)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\computation\expressions.py:131, in _evaluate_numexpr(op, op_str, a, b)
#     130 if result is None:
# --> 131     result = _evaluate_standard(op, op_str, a, b)
#     133 return result
#
# ...

# %%
df01 = pd.DataFrame(matrix, columns=list('abcde'))
df01
# Out:
#     a   b   c   d   e
# 0  15  12  14   4   1
# 1  15  17  13   9  15
# 2  10  19   5  18  10
# 3   8   7  11   1   2
# 4  11  19  19  10   7

# %%
df01.apply(lambda x: x**2)
# Out:
#      a    b    c    d    e
# 0  225  144  196   16    1
# 1  225  289  169   81  225
# 2  100  361   25  324  100
# 3   64   49  121    1    4
# 4  121  361  361  100   49

# %%
df01
# Out:
#     a   b   c   d   e
# 0  15  12  14   4   1
# 1  15  17  13   9  15
# 2  10  19   5  18  10
# 3   8   7  11   1   2
# 4  11  19  19  10   7

# %%
df02=df01.apply(lambda x: x**3)
df02
# Out:
#       a     b     c     d     e
# 0  3375  1728  2744    64     1
# 1  3375  4913  2197   729  3375
# 2  1000  6859   125  5832  1000
# 3   512   343  1331     1     8
# 4  1331  6859  6859  1000   343

# %%
df01
# Out:
#     a   b   c   d   e
# 0  15  12  14   4   1
# 1  15  17  13   9  15
# 2  10  19   5  18  10
# 3   8   7  11   1   2
# 4  11  19  19  10   7

# %%
df02
# Out:
#       a     b     c     d     e
# 0  3375  1728  2744    64     1
# 1  3375  4913  2197   729  3375
# 2  1000  6859   125  5832  1000
# 3   512   343  1331     1     8
# 4  1331  6859  6859  1000   343

# %%
df02.apply(np.sqrt)
# Out:
#            a          b          c          d          e
# 0  58.094750  41.569219  52.383203   8.000000   1.000000
# 1  58.094750  70.092796  46.872167  27.000000  58.094750
# 2  31.622777  82.819080  11.180340  76.367532  31.622777
# 3  22.627417  18.520259  36.482873   1.000000   2.828427
# 4  36.482873  82.819080  82.819080  31.622777  18.520259

# %%
df01['a'] = df01['a'].apply(np.sqrt)
df01
# Out:
#           a   b   c   d   e
# 0  3.872983  12  14   4   1
# 1  3.872983  17  13   9  15
# 2  3.162278  19   5  18  10
# 3  2.828427   7  11   1   2
# 4  3.316625  19  19  10   7

# %%
df01 = pd.DataFrame({'Team':['MI','CSK','RCB','KKR'],
                     'Captain':['Rohit','Gaikwad','Virat','Gautam']
                    })
df01
# Out:
#   Team  Captain
# 0   MI    Rohit
# 1  CSK  Gaikwad
# 2  RCB    Virat
# 3  KKR   Gautam

# %%
df01['Captain']=df01['Captain'].apply(lambda x: x.upper())
df01
# Out:
#   Team  Captain
# 0   MI    ROHIT
# 1  CSK  GAIKWAD
# 2  RCB    VIRAT
# 3  KKR   GAUTAM

# %%
df01 = pd.DataFrame({'Team':['MI','CSK','RCB','KKR'],
                     'Captain':['Rohit Sharma','Ruturaj Gaikwad','Virat Kohli','Gautam Gambhir']
                    })
df01
# Out:
#   Team          Captain
# 0   MI     Rohit Sharma
# 1  CSK  Ruturaj Gaikwad
# 2  RCB      Virat Kohli
# 3  KKR   Gautam Gambhir

# %%
df01['Captain'] = df01['Captain'].apply(lambda x: x.lower())
df01
# Out:
#   Team          Captain
# 0   MI     rohit sharma
# 1  CSK  ruturaj gaikwad
# 2  RCB      virat kohli
# 3  KKR   gautam gambhir

# %%
df01
# Out:
#   Team          Captain
# 0   MI     rohit sharma
# 1  CSK  ruturaj gaikwad
# 2  RCB      virat kohli
# 3  KKR   gautam gambhir

# %%
df01['Captain'] = df01['Captain'].apply(lambda x: x.title())
df01
# Out:
#   Team          Captain
# 0   MI     Rohit Sharma
# 1  CSK  Ruturaj Gaikwad
# 2  RCB      Virat Kohli
# 3  KKR   Gautam Gambhir

# %%
df01
# Out:
#   Team          Captain
# 0   MI     Rohit Sharma
# 1  CSK  Ruturaj Gaikwad
# 2  RCB      Virat Kohli
# 3  KKR   Gautam Gambhir

# %%
df01['Captain'] = df01['Captain'].apply(lambda x: x.swapcase())
df01
# Out:
#   Team          Captain
# 0   MI     rOHIT sHARMA
# 1  CSK  rUTURAJ gAIKWAD
# 2  RCB      vIRAT kOHLI
# 3  KKR   gAUTAM gAMBHIR

# %%
df01['Captain'] = df01['Captain'].apply(lambda x: x.title())
df01
# Out:
#   Team          Captain
# 0   MI     Rohit Sharma
# 1  CSK  Ruturaj Gaikwad
# 2  RCB      Virat Kohli
# 3  KKR   Gautam Gambhir

# %%
df01['Captain'] = df01['Captain'].apply(lambda x: x
